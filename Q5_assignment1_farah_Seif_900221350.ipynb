# %% [markdown]
# <a href="https://colab.research.google.com/github/FarahSeif/FarahSeif/blob/main/Q5_assignment1_farah_Seif_900221350.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
path1="/200 participant collected data.xlsx"
df2=pd.read_excel(path1)
df2
# Out:
#      Participant Number  Gender   Age Dominant Hand  \
# 0                   101    Male   NaN         Right
# 1                   102    Male   NaN         Right
# 2                   103    Male   NaN         Right
# 3                   104    Male   NaN         Right
# 4                   105    Male  18.0         Right
# ..                  ...     ...   ...           ...
# 195                 296  Female   NaN         Right
# 196                 297    Male  19.0         Right
# 197                 298    Male  22.0         Right
# 198                 299    Male  23.0         Right
# 199                 300  Female  26.0         Right
#
#      Height (cm) (average of 3 measurments)  \
# 0                                174.000000
# 1                                202.000000
# 2                                182.333333
# 3                                184.000000
# 4                                180.666667
# ..                                      ...
# ...

# %%
np.mean(df2['Height (cm) (average of 3 measurments)'])
# Out:
# 173.17

# %%
Ages=df2['Age']
Ages
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4      18.0
#        ...
# 195     NaN
# 196    19.0
# 197    22.0
# 198    23.0
# 199    26.0
# Name: Age, Length: 200, dtype: float64

# %%
d={'Ages':df2['Age']}
d
# Out:
# {'Ages': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4      18.0
#         ...
#  195     NaN
#  196    19.0
#  197    22.0
#  198    23.0
#  199    26.0
#  Name: Age, Length: 200, dtype: float64}

# %%
d['age_bins'] = pd.cut(x=d['Ages'], bins=[18,19,20,21,22,23,24,25,27])
d
# Out:
# {'Ages': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4      18.0
#         ...
#  195     NaN
#  196    19.0
#  197    22.0
#  198    23.0
#  199    26.0
#  Name: Age, Length: 200, dtype: float64,
#  'age_bins': 0               NaN
#  1               NaN
#  2               NaN
#  3               NaN
#  4               NaN
#             ...
#  195             NaN
#  196    (18.0, 19.0]
#  197    (21.0, 22.0]
#  198    (22.0, 23.0]
#  199    (25.0, 27.0]
#  Name: Age, Length: 200, dtype: category
#  Categories (8, interval[int64, right]): [(18, 19] < (19, 20] < (20, 21] < (21, 22] < (22, 23] <
#                                           (23, 24] < (24, 25] < (25, 27]]}

# %%
df2.groupby(['Age']).agg(average_height=("Height (cm) (average of 3 measurments)","median"))
# Out:
#       average_height
# Age
# 18.0      170.000000
# 19.0      172.333333
# 20.0      175.000000
# 21.0      174.666667
# 22.0      174.333333
# 23.0      172.333333
# 24.0      166.833333
# 25.0      176.000000
# 26.0      165.500000
# 28.0      173.500000
# 29.0      174.666667
# 34.0      176.666667
# 38.0      165.333333
# 39.0      165.500000
# 41.0      182.333333
# 42.0      160.333333
# 56.0      152.000000
